# %%
# Packages
############################
'''
Template for the 4th assignment
Student: Fabian Gobet
'''
import os
os.environ['PYTORCH_ENABLE_MPS_FALLBACK'] = '1'

from accelerate import Accelerator
import torch
import torch.nn as nn
import math
import random
import re
import statistics
from nltk.tokenize.treebank import TreebankWordTokenizer
import pickle
import os
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split

# %%
# Classes
############################
# Vocabulary class
class Vocabulary:
    '''
    Class for dealing with our corpus
    '''

    def __init__(self, name, sentences):
        """
        Args:
            name (str): name of the language
            pairs (list): list of pairs of sentences
        """
        self.name = name
        self.word2index = {"<PAD>": 0, "<SOS>": 1, "<EOS>": 2}
        self.index2word = {0: "<PAD>", 1: "<SOS>", 2: "<EOS>"}
        for s in sentences:
            self.add_sentence(s)


    def add_word(self, word):
        '''
        Add a word to the vocabulary
        :param word: a string
        '''
        # TODO: add the word to the vocabulary
        if not word in self.word2index:
            self.word2index[word] = len(self.word2index)
            self.index2word[len(self.index2word)] = word


    def add_sentence(self, sentence):
        '''
        Add a sentence to the vocabulary
        :param sentence: list of strings (words)
        '''
        # TODO add the sentence to the vocabulary, this method will call the add_word method
        for word in sentence:
            self.add_word(word)


# Dataset class
class Dataset(torch.utils.data.Dataset):
    def __init__(self, vocabulary, pairs_refs, sentences):
        # TODO We want vocabulary and pairs to be attributes of the class
        self.vocabulary = vocabulary
        self.pairs = pairs_refs
        self.sentences = sentences

    def __len__(self):
        # TODO how many pairs do we have?
        return len(self.pairs)

    def __getitem__(self, ix):
        # TODO returns two tensors (question, answer) of the pair at index ix
        # TODO the tensors should be of type torch.tensor and should contain integers (word indices)
        q,a = self.pairs[ix]
        q = torch.tensor([self.vocabulary.word2index[word] for word in self.sentences[q]])
        a = torch.tensor([self.vocabulary.word2index[word] for word in ["<SOS>"]+self.sentences[a]])
        return q,a


class PositionalEncoding(nn.Module):
    '''
    Adapted from
    https://pytorch.org/tutorials/beginner/transformer_tutorial.html
    '''
    def __init__(self, d_model, dropout=0.0, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        self.max_len = max_len

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float()
                             * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        try:
            assert x.size(0) < self.max_len
        except:
            print("The length of the sequence is bigger than the max_len of the positional encoding. Increase the max_len or provide a shorter sequence.")
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model=512, pad_id=0, encoder_layers=6, decoder_layers=6, dim_feedforward=2048, num_heads=8, dropout_transformer=0.1, dropout_posenconding=0):
        super().__init__()

        # TODO add an embedding layer
        self.embedding = nn.Embedding(vocab_size, d_model)

        # TODO add a positional encoding layer
        self.pos_encoder = PositionalEncoding(d_model,dropout=dropout_posenconding)

        # TODO add a transformer layer, you can use nn.Transformer. You can use the default values for the parameters, but what about batch_first?
        self.transformer = nn.Transformer(d_model=d_model, nhead=num_heads, num_encoder_layers=encoder_layers, 
                                          num_decoder_layers=decoder_layers, dim_feedforward=dim_feedforward, dropout=dropout_transformer, 
                                          batch_first=True)

        # TODO add a linear layer. Note: output should be probability distribution over the vocabulary
        self.linear = nn.Linear(d_model, vocab_size)

        # Stuff you may need
        self.vocab_size = vocab_size
        self.pad_id = pad_id
        self.num_heads = num_heads

    def create_padding_mask(self, x, pad_id=0):
        # TODO create a boolean mask for the <PAD> tokens
        return x.eq(pad_id)

    def forward(self, src, tgt):
        # S is the source sequence length, T is the target sequence length, N is the batch size, E is the feature number
        # src: (N, S)
        # tgt: (N, T)
        # src_pad_mask: (N, S)
        # tgt_pad_mask: (N, T)
        # mask the future : (N * num_heads, T, T)

        src_pad_mask = self.create_padding_mask(src, self.pad_id) # (N, S)
        tgt_pad_mask = self.create_padding_mask(tgt, self.pad_id) # (N, T)

        src = self.embedding(src)
        tgt = self.embedding(tgt)

        src = self.pos_encoder(src)  # (N, S, E)
        tgt = self.pos_encoder(tgt) # (N, T, E)

        # Mask the memory
        memory_key_padding_mask = src_pad_mask  # (N, S)

        # Mask the future
        tgt_mask = self.transformer.generate_square_subsequent_mask(tgt.size(1), dtype=torch.bool).to(tgt.device) # (T, T)

        # Expand to make it N * num_heads, T, T
        tgt_mask = tgt_mask.unsqueeze(0).repeat(tgt.size(0) * self.num_heads, 1, 1) # (N, T, T)

        # Transformer
        output = self.transformer(src, tgt, tgt_mask=tgt_mask, src_key_padding_mask=src_pad_mask,
                            tgt_key_padding_mask=tgt_pad_mask, memory_key_padding_mask=memory_key_padding_mask) # (N, T, E)
        # Linear layer
        output = self.linear(output) # (N, T, V)
        return output

# %%
# Methods
############################

def pickle_dump(obj, PATH, name):
    if not os.path.exists(PATH):
        os.makedirs(PATH)

    with open(PATH+name, 'wb') as f:
        pickle.dump(obj, f)

def pickle_load(PATH):
    with open(PATH, 'rb') as f:
        obj = pickle.load(f)
    return obj

def print_random_elements(collection, k=5):
    random_elements = random.sample(collection, k=k)
    for e in random_elements:
        print(e)

def collate_fn(batch,pad_idx):
  data, targets = zip(*batch)
  padded_data = nn.utils.rnn.pad_sequence(data, batch_first=True, padding_value=pad_idx)
  padded_targets = nn.utils.rnn.pad_sequence(targets, batch_first=True, padding_value=pad_idx)
  return padded_data, padded_targets

def checkpoint(model,optimizer,path='./MyFiles/',save_name=None):
  dic = {
      'model_state' : model.state_dict(),
      'optimizer' : optimizer.state_dict()
  }
  if save_name is not None:
    torch.save(dic, path+save_name+".pt")
  return dic

def load_checkpoint(path,toCPU=False):
    if toCPU:
      checkpoint = torch.load(path,map_location=torch.device('cpu'))
    else:
      checkpoint = torch.load(path)
    model_state = checkpoint['model_state']
    optimizer_state = checkpoint['optimizer']
    return model_state,optimizer_state

def check_content_txt_files(convo_path, lines_path, num_elements):
    with open(convo_path, 'r') as conv_file:
        for i in range(num_elements):
            print(conv_file.readline())

    with open(lines_path, 'r') as lines_file:
        for i in range(num_elements):
            print(lines_file.readline())

def get_reference_pairs(convo_path):
    ref_pairs = []
    with open(convo_path, 'r') as conv_file:
        for line in conv_file:
            conversation = line.strip().split(' +++$+++ ')[-1][1:-1].replace("'", "").split(",")
            for i in range(len(conversation) - 1):
                ref_pairs.append((conversation[i].strip(), conversation[i+1].strip()))
    return ref_pairs


def normalize_sentences(path_lines):
    lines_dict = {}
    empty_lines = 0
    with open(path_lines, 'r', encoding='cp1252') as lines_file:
        for full_line in lines_file:
            line_split = full_line.split(' +++$+++ ')
            line = line_split[-1]
            line, is_line_empty = process_sentence(line)
            if is_line_empty == 1:
                empty_lines += 1
            else:
                lines_dict.update({line_split[0] : line})
    return lines_dict, empty_lines

def process_sentence(line):
    is_line = 0
    line = line.replace('\n','').replace("<u>","").replace("</u>","").lower()
    line = re.sub('-+','',line)
    line = re.sub(r"\'s", " is", line, flags=re.I)
    line = re.sub(r"can't", "can not", line, flags=re.I)
    line = re.sub(r"\'bout", "about", line, flags=re.I)
    line = re.sub(r"\'til", "until", line, flags=re.I)
    line = re.sub(r"\'till", "until", line, flags=re.I)
    line = re.sub(r"\'m", " am", line, flags=re.I)
    line = re.sub(r"\'cause", "because", line, flags=re.I)
    line = re.sub(r"\'ll", " will", line, flags=re.I)
    line = re.sub(r"\'em", " them", line, flags=re.I)
    line = re.sub(r"\'ve", " have", line, flags=re.I)
    line = re.sub(r"\'re", " are", line, flags=re.I)
    line = re.sub(r"\'d", " would", line, flags=re.I)
    line = re.sub(r"n't", " not", line, flags=re.I)
    line = re.sub(r"[^a-zA-Z.?,!]+", r" ", line)
    line = line.strip()
    if line == '' or line.isspace():
        is_line += 1
    else:
        line = TreebankWordTokenizer().tokenize(line)
    return line, is_line

def get_valid_refs(ref_pairs, lines):
    valid_refs = set()
    for p in ref_pairs:
        if p[0] in lines and p[1] in lines:
            valid_refs.add(p[0])
            valid_refs.add(p[1])
    return valid_refs

def generate_primitive_valid_pairs(all_ref_pairs, lines):
    chosen_sentences = {}
    chosen_ref_pairs = []

    for p in all_ref_pairs:
        if p[0] in lines and p[1] in lines:
            chosen_sentences.update({p[0]: lines[p[0]]+['<EOS>'], p[1]: lines[p[1]]+['<EOS>']})
            chosen_ref_pairs.append(p)
    return chosen_sentences, chosen_ref_pairs

def eliminate_long_sentences(chosen_sentences, chosen_ref_pairs, max_length):
    rule_out_sentences_refs = set()
    chosen_sentences2 = {}
    chosen_ref_pairs2 = []

    for k,v in chosen_sentences.items():
        if len(v) > max_length:
            rule_out_sentences_refs.add(k)

    for p in chosen_ref_pairs:
        if p[0] not in rule_out_sentences_refs and p[1] not in rule_out_sentences_refs:
            chosen_sentences2.update({p[0]: chosen_sentences[p[0]]})
            chosen_sentences2.update({p[1]: chosen_sentences[p[1]]})
            chosen_ref_pairs2.append(p)

    return chosen_sentences2,chosen_ref_pairs2,rule_out_sentences_refs

def eliminate_sentences_with_rare_words(chosen_sentences, chosen_ref_pairs, rule_out_words):
    rule_out_sentences_refs = set()
    chosen_sentences2 = {}
    chosen_ref_pairs2 = []

    for k,v in chosen_sentences.items():
        if any(word in rule_out_words for word in v):
            rule_out_sentences_refs.add(k)

    for p in chosen_ref_pairs:
        if p[0] not in rule_out_sentences_refs and p[1] not in rule_out_sentences_refs:
            chosen_sentences2.update({p[0]: chosen_sentences[p[0]]})
            chosen_sentences2.update({p[1]: chosen_sentences[p[1]]})
            chosen_ref_pairs2.append(p)

    return chosen_sentences2,chosen_ref_pairs2,rule_out_sentences_refs

def count_words(chosen_ref_pairs, chosen_sentences):
    word_counts = {}
    for p in chosen_ref_pairs:
        for r in p:
            for w in chosen_sentences[r]:
                if w in word_counts:
                    word_counts[w] += 1
                else:
                    word_counts[w] = 1
    num_words = sum(word_counts.values())
    return word_counts, num_words


def extract_sentences_from_refs(chosen_ref_pairs, chosen_sentences):
    chosen_sentences2 = {}
    for p in chosen_ref_pairs:
        chosen_sentences2.update({p[0]: chosen_sentences[p[0]]})
        chosen_sentences2.update({p[1]: chosen_sentences[p[1]]})
    return chosen_sentences2


def create_pairs(path='./MyFiles/',savename="result",max_length=26,word_frequency_discard=10,verbose=True):

    if verbose:
        check_content_txt_files('./movie_conversations.txt', './movie_lines.txt', 5)

    all_ref_pairs = get_reference_pairs('./movie_conversations.txt')

    if verbose:
        print_random_elements(all_ref_pairs)

    lines,empty_lines = normalize_sentences('./movie_lines.txt')

    if verbose:
        print('Number of empty lines: {}'.format(empty_lines))
        print_random_elements(list(lines.values()))

    chosen_sentences, chosen_ref_pairs = generate_primitive_valid_pairs(all_ref_pairs, lines)

    if verbose:
        print_random_elements(chosen_ref_pairs)

        sentence_lengths = []
        for p in chosen_ref_pairs:
            sentence_lengths.append(len(chosen_sentences[p[0]]))
            sentence_lengths.append(len(chosen_sentences[p[1]]))

        mean_length = statistics.mean(sentence_lengths)
        std_dev = statistics.stdev(sentence_lengths)

        print('Mean sentence length: {}'.format(mean_length))
        print('Standard deviation: {}'.format(std_dev))
        print('Max sentence length: {}'.format(max(sentence_lengths)))
        print('Min sentence length: {}'.format(min(sentence_lengths)))


        plt.hist(sentence_lengths, density=True, bins=40)
        plt.xlabel('Sentence Length')
        plt.ylabel('Frequency (log scale)')
        plt.title('Sentence Length Distribution')
        plt.yscale('log')  
        plt.axvline(x=mean_length, color='r', linestyle='--', label='Mean')  
        plt.legend()
        plt.show()

        length_counts = {}
        for length in sentence_lengths:
            if length in length_counts:
                length_counts[length] += 1
            else:
                length_counts[length] = 1


        sorted_lengths = sorted(length_counts.keys())

        total_sentences = len(sentence_lengths)
        accumulated_percentage = 0
        percentage_values = []
        for length in sorted_lengths:
            frequency = length_counts[length]
            percentage = (frequency / total_sentences) * 100
            accumulated_percentage += percentage
            percentage_values.append(accumulated_percentage)

        plt.plot(sorted_lengths, percentage_values)
        plt.xlabel('Sentence Length')
        plt.ylabel('Accumulated Frequency Percentage')
        plt.title('Sentence Length Distribution')
        plt.show()

    initial_num_sentences = len(chosen_sentences)
    initial_num_pairs = len(chosen_ref_pairs)
    chosen_sentences2,chosen_ref_pairs2,rule_out_sentences_refs = eliminate_long_sentences(chosen_sentences, chosen_ref_pairs, max_length)

    if verbose:
        print('Initial number of sentences: {}'.format(initial_num_sentences))
        print('Current number of senteces: {}'.format(initial_num_sentences-len(rule_out_sentences_refs)))
        print('Initial number of pairs: {}'.format(initial_num_pairs))
        print('Current number of pairs: {}'.format(initial_num_pairs-len(chosen_ref_pairs2)))


    word_counts, num_words = count_words(chosen_ref_pairs2, chosen_sentences2)

    if verbose:
        print('Number of words: {}'.format(num_words))
        print('Number of unique words: {}'.format(len(word_counts)))

        plt.plot(range(len(word_counts)), list(word_counts.values()))
        plt.xlabel('Word index')
        plt.ylabel('Word frequency')
        plt.suptitle('Word frequency distribution')
        plt.title('Frequency per word')
        plt.show()

        # Compute the mean and standard deviation for word counts
        mean_value = statistics.mean(word_counts.values())
        print("Mean value:", mean_value)
        print("Max value:", max(word_counts.values()))
        print("Min value:", min(word_counts.values()))

        # Plot the distribution of word counts < mean
        dict_lower_mean = {k: v for k, v in word_counts.items() if v < mean_value}
        sorted_dict_lower_mean = dict(sorted(dict_lower_mean.items(), key=lambda x: x[1], reverse=True))

        plt.plot(range(len(sorted_dict_lower_mean)), sorted_dict_lower_mean.values())
        plt.xlabel('Word index')
        plt.ylabel('Word count')
        plt.suptitle('Word count distribution')
        plt.title('Words with count < mean')
        plt.show()

    # Frequency threshold and filter out the words that are too rare
    rule_out_words = [k for k, v in word_counts.items() if v < word_frequency_discard]
    chosen_sentences3,chosen_ref_pairs3,rule_out_sentences_refs = eliminate_sentences_with_rare_words(chosen_sentences2, chosen_ref_pairs2, rule_out_words)

    if verbose:
        print('Current number of senteces: {} ({:.2f}% of total)'.format(initial_num_sentences-len(chosen_sentences3),(initial_num_sentences-len(chosen_sentences3))/initial_num_sentences*100))
        print('Current number of pairs: {} ({:.2f}% of total)'.format(initial_num_pairs-len(chosen_ref_pairs3),(initial_num_pairs-len(chosen_ref_pairs3))/initial_num_pairs*100))

    # Save the pairs to a pickle file


    pickle_dump(chosen_sentences3,path,savename+"_sentences.pkl")
    pickle_dump(chosen_ref_pairs3,path,savename+"_ref_pairs.pkl")

    return chosen_sentences3,chosen_ref_pairs3


def evaluate(val_loader, model, criterion, device):
      model.eval()
      total_loss = 0
      with torch.no_grad():
          for data, targets in val_loader:
              data = data.to(device)
              targets_trim = targets[:,:-1].contiguous().to(device)
              outputs = model(data,targets_trim)
              targets_trim = targets[:,1:].contiguous().to(device).view(-1 )
              loss = criterion(outputs.view(-1,outputs.size(-1)), targets_trim)
              total_loss += loss.item()
      model.train()
      return total_loss / len(val_loader)

def train(epochs, model, criterion, optimizer, train_loader, device, val_loader, lr_scheduler, eval_every_n_batches):
    train_losses = []
    val_losses = []
    vocab = train_loader.dataset.vocabulary
    optimizer.zero_grad()
    running_loss = 0

    for epoch in range(epochs):
        steps=0
        for i, (data, targets) in enumerate(train_loader):
            steps += 1
            model.train()
            data = data.to(device)
            targets_trim = targets[:,:-1].contiguous().to(device)
            outputs = model(data,targets_trim)
            targets_trim = targets[:,1:].contiguous().to(device)
            loss = criterion(outputs.view(outputs.size(0)*outputs.size(1),outputs.size(2)),targets_trim.view(targets_trim.size(0)*targets_trim.size(1)))
            running_loss += loss.item() 
            loss.backward()
            optimizer.step()

            if (i+1) % eval_every_n_batches == 0 or (i+1) == len(train_loader):
                train_losses.append(running_loss/steps)
                running_loss = 0
                steps = 0
                val_losses.append(evaluate(val_loader, model, criterion, device))
                if lr_scheduler:
                    lr_scheduler.step(val_losses[-1])
                random_index = random.randint(0, len(targets)-1)
                target_sentence = " ".join([vocab.index2word[idx.item()] for idx in targets[random_index][1:]])
                output_sentence = " ".join([vocab.index2word[idx.item()] for idx in outputs.argmax(dim=-1)[random_index]])

                print(f"Epoch: {epoch+1}/{epochs}, Batch: {i+1}/{len(train_loader)}")
                print(f"Train Loss: {train_losses[-1]:.4f}")
                print(f"Validation Loss: {val_losses[-1]:.4f}")
                print(f"Random Target Sentence: {target_sentence}")
                print(f"Random Output Sentence: {output_sentence}\n")
            optimizer.zero_grad()

    return train_losses, val_losses, model, optimizer

def train_ga(epochs, model, criterion, optimizer, train_loader, device, val_loader, accumulation_batches, lr_scheduler, eval_every_n_batches=32):

    assert  eval_every_n_batches % accumulation_batches == 0 and eval_every_n_batches >= accumulation_batches, "eval_every_n_batches must be a multiple of accumulation_batches"
    assert  len(train_loader) % eval_every_n_batches == 0 and len(train_loader) >= eval_every_n_batches, "eval_every_n_batches must be a multiple of len(train_loader)"

    train_losses = []
    val_losses = []
    vocab = train_loader.dataset.vocabulary
    optimizer.zero_grad()
    running_loss = 0


    for epoch in range(epochs):
        for i, (data, targets) in enumerate(train_loader):
          model.train()
          data = data.to(device)
          targets_trim = targets[:,:-1].contiguous().to(device)
          outputs = model(data,targets_trim)
          targets_trim = targets[:,1:].contiguous().to(device)
          loss = criterion(outputs.view(outputs.size(0)*outputs.size(1),outputs.size(2)),targets_trim.view(targets_trim.size(0)*targets_trim.size(1)))
          loss = loss / accumulation_batches
          running_loss += loss.item() 
          loss.backward()

          if (i+1) % accumulation_batches == 0 or (i+1) == len(train_loader):
              train_losses.append(running_loss)
              running_loss = 0
              if (i+1) % eval_every_n_batches == 0 or (i+1) == len(train_loader):
                val_losses.append(evaluate(val_loader, model, criterion, device))
                optimizer.step()
                if lr_scheduler:
                  lr_scheduler.step(val_losses[-1])
              else:
                optimizer.step()
              optimizer.zero_grad()

              if (i+1) % eval_every_n_batches == 0 or (i+1) == len(train_loader):
                random_index = random.randint(0, len(targets)-1)
                target_sentence = " ".join([vocab.index2word[idx.item()] for idx in targets[random_index][1:]])
                output_sentence = " ".join([vocab.index2word[idx.item()] for idx in outputs.argmax(dim=-1)[random_index]])

                print(f"Epoch: {epoch+1}/{epochs}, Batch: {i+1}/{len(train_loader)}")
                print(f"Train Loss: {train_losses[-1]:.4f}")
                print(f"Validation Loss: {val_losses[-1]:.4f}")
                print(f"Random Target Sentence: {target_sentence}")
                print(f"Random Output Sentence: {output_sentence}\n")

    return train_losses, val_losses, model, optimizer


def get_greedy_answer(model, question, vocab, device, max_length=20):
    line,_ = process_sentence(question)
    line = line+['<EOS>']
    line = [vocab.word2index.get(word, vocab.word2index["<PAD>"]) for word in line]
    line = torch.tensor(line, dtype=torch.long).unsqueeze(0).to(device)
    target = torch.tensor([vocab.word2index["<SOS>"]], dtype=torch.long).unsqueeze(0).to(device)
    model.eval()
    with torch.no_grad():
        for _ in range(max_length):
            output = model(line,target)
            output = output.argmax(dim=-1)[:,-1]
            if output.item() == vocab.word2index["<EOS>"]:
                break
            target = torch.cat((target,output.unsqueeze(0)),dim=1)
    answer = " ".join([vocab.index2word[idx.item()] for idx in target.squeeze()[1:]])
    return answer


def get_topk_answers(model, question, vocab, device, k=5, max_length=20):
    line,_ = process_sentence(question)
    line = line+['<EOS>']
    line = [vocab.word2index.get(word, vocab.word2index["<PAD>"]) for word in line]
    line = torch.tensor(line).unsqueeze(0).to(device)
    target = torch.tensor([vocab.word2index["<SOS>"]], dtype=torch.long).unsqueeze(0).to(device)
    model.eval()
    with torch.no_grad():
        for _ in range(max_length):
            output = model(line,target)
            output = F.softmax(output, dim=-1)[0,-1,:].detach().cpu()
            topk_logits, topk_indices = torch.topk(output,k=k,dim=-1)
            p = F.softmax(topk_logits, dim=-1).numpy()
            w_idx = np.random.choice(topk_indices.squeeze(), p=p)
            if w_idx == vocab.word2index["<EOS>"]:
                break
            w_idx = torch.tensor(w_idx, dtype=torch.long).unsqueeze(0).unsqueeze(0).to(device)
            target = torch.cat((target,w_idx),dim=1)
    target = [vocab.index2word[idx.item()] for idx in target.squeeze()[1:]]
    return " ".join(target)

def train_ga_hf(epochs, model, optimizer, criterion, train_loader, val_loader, device, lr_scheduler, accumulation_steps):
    accelerator = Accelerator(gradient_accumulation_steps=accumulation_steps)
    model, optimizer, train_loader, lr_scheduler = accelerator.prepare(model, optimizer, train_loader, lr_scheduler)

    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        for i, (data, targets) in enumerate(train_loader):
            with accelerator.accumulate(model):
                data, targets = data.to(device), targets.to(device)
                output = model(data, targets[:, :-1])
                loss = criterion(output.view(-1, output.size(-1)), targets[:, 1:].contiguous().view(-1))
                train_losses.append(loss.item())
                accelerator.backward(loss)
                optimizer.step()
                if lr_scheduler and (i+1) % accumulation_steps==0:
                    val_losses.append(evaluate(model, criterion, val_loader, device))
                    lr_scheduler.step()
                optimizer.zero_grad()
    return train_losses, val_losses, model

# %%
chosen_sentences, chosen_ref_pairs = create_pairs(path='./',savename="result",max_length=26,word_frequency_discard=10,verbose=True)

# %%
# Dump QA chosen_sentences
############################
PATH = './'
with open(PATH+'qa_chosen_dump.txt', 'w') as qa_dump:
    for s in list(chosen_sentences.values()):
        s_temp = " ".join(s)
        qa_dump.write(s_temp+"\n\n")

# %%
# !!! Don't change the seed !!!
torch.manual_seed(42)
# !!!!!!


# Load pairs
PATH = './'
chosen_sentences = pickle_load(PATH+'result_sentences.pkl')
chosen_ref_pairs = pickle_load(PATH+'result_ref_pairs.pkl')

# %%
# !!! Don't change the seed !!!
torch.manual_seed(42)
# !!!!!!

# Pipeline parameters
############################
# Hyperparameters
device = torch.device("mps" if torch.mps.is_available() else "cpu")
batch_size = 64 
accumulation_batches = 4 
rand_sample_num = 40960
learning_rate = 1e-4
d_model = 256
encoder_layers = 4
decoder_layers = 4
feed_forward_dim = 1024
nheads = 8
dropout_transformer = 0.4
dropout_posenconding = 0.1
patience = 3
epochs = 10
eval_every_n_batches = 32 # 4 evaluations per epoch

# %%
PATH = './'
chosen_sentences = pickle_load(PATH+'chosen_sentences_'+str(rand_sample_num)+'.pkl')
train_pairs = pickle_load(PATH+'train_pairs_'+str(rand_sample_num)+'.pkl')
val_pairs = pickle_load(PATH+'val_pairs_'+str(rand_sample_num)+'.pkl')
test_pairs = pickle_load(PATH+'test_pairs_'+str(rand_sample_num)+'.pkl')

# %%
rand_sample_num = min(rand_sample_num,len(chosen_ref_pairs))
chosen_ref_pairs = random.sample(chosen_ref_pairs,rand_sample_num)
all_refs = set()
for p in chosen_ref_pairs:
  all_refs.add(p[0])
  all_refs.add(p[1])
chosen_sentences = {k:v for k,v in chosen_sentences.items() if k in all_refs}
train_size = (int(0.8 * rand_sample_num)//batch_size)*batch_size
val_size = (rand_sample_num-train_size)//2
test_size = rand_sample_num-train_size-val_size
train_pairs, val_pairs, test_pairs = random_split(chosen_ref_pairs,[train_size,val_size,test_size])

PATH = './'
pickle_dump(chosen_sentences, PATH,'chosen_sentences_'+str(rand_sample_num)+'.pkl')
pickle_dump(train_pairs, PATH,'train_pairs_'+str(rand_sample_num)+'.pkl')
pickle_dump(val_pairs, PATH,'val_pairs_'+str(rand_sample_num)+'.pkl')
pickle_dump(test_pairs, PATH,'test_pairs_'+str(rand_sample_num)+'.pkl')

# %%
# Vocabulary, Dataset and Dataloader
vocab = Vocabulary("English",chosen_sentences.values())
train_dataset = Dataset(vocab,train_pairs,extract_sentences_from_refs(train_pairs, chosen_sentences))
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,collate_fn=lambda batch: collate_fn(batch,vocab.word2index["<PAD>"]))
val_dataset = Dataset(vocab,val_pairs,extract_sentences_from_refs(val_pairs, chosen_sentences))
val_loader = DataLoader(val_dataset,batch_size=batch_size,shuffle=False,collate_fn=lambda batch: collate_fn(batch,vocab.word2index["<PAD>"]))
test_dataset = Dataset(vocab,test_pairs,extract_sentences_from_refs(test_pairs, chosen_sentences))
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,collate_fn=lambda batch: collate_fn(batch,vocab.word2index["<PAD>"]))

# %%
# Dump QA dataset
############################
PATH = './'
with open(PATH+'qa_dataset_dump.txt', 'w') as qa_dump:
    for Q,A in train_dataset:
        q = " ".join([vocab.index2word[i.item()] for i in Q])
        a = " ".join([vocab.index2word[i.item()] for i in A])
        qa_dump.write("Q: "+q+"\nA: "+a+"\n\n")

# %%
pickle_dump(vocab.index2word, PATH,'index2word_'+str(rand_sample_num)+'.pkl')
pickle_dump(vocab.word2index, PATH,'word2index_'+str(rand_sample_num)+'.pkl')

# %%
vocab.index2word = pickle_load(PATH+'index2word_'+str(rand_sample_num)+'.pkl')
vocab.word2index = pickle_load(PATH+'word2index_'+str(rand_sample_num)+'.pkl')

# %%
# Pipeline initialization
############################
# Model, criterion, optimizer and scheduler
model = TransformerModel(vocab_size=len(vocab.word2index),d_model=d_model,pad_id=vocab.word2index["<PAD>"],
                        encoder_layers=encoder_layers,decoder_layers=decoder_layers,dim_feedforward=feed_forward_dim,
                        num_heads=nheads,dropout_transformer=dropout_transformer, dropout_posenconding=dropout_posenconding).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=vocab.word2index["<PAD>"])
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,'min',patience=patience, factor=0.8)

# %%
train_losses, val_losses, model, optimizer = train(epochs, model, criterion, optimizer, train_loader, device, val_loader, lr_scheduler, eval_every_n_batches)
# Out:
# Epoch: 1/20, Batch: 32/512
# Train Loss: 8.3213
# Validation Loss: 7.3787
# Random Target Sentence: but you were saying you were <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 64/512
# Train Loss: 7.2930
# Validation Loss: 6.6222
# Random Target Sentence: i do not care i wan na hear more <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 96/512
# Train Loss: 6.6232
# Validation Loss: 6.1103
# Random Target Sentence: i do not remember we kissed at my door and next thing i knew i woke up with my period alone <EOS> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 128/512
# Train Loss: 6.1336
# Validation Loss: 5.8616
# Random Target Sentence: why of course you can come on in the office here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 160/512
# Train Loss: 5.9167
# Validation Loss: 5.7657
# Random Target Sentence: what about it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 192/512
# Train Loss: 5.7741
# Validation Loss: 5.7289
# Random Target Sentence: why not you mind your own business chief <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 224/512
# Train Loss: 5.7178
# Validation Loss: 5.7189
# Random Target Sentence: perhaps you would rather discuss it personally with the president <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 256/512
# Train Loss: 5.6940
# Validation Loss: 5.7134
# Random Target Sentence: what difference does it make why i do it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 288/512
# Train Loss: 5.7065
# Validation Loss: 5.7097
# Random Target Sentence: well i am glad you got it out of your system congratulations mission accomplished <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 320/512
# Train Loss: 5.6850
# Validation Loss: 5.7114
# Random Target Sentence: never send a boy to do a woman is job with me we can do it in seven <EOS> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 352/512
# Train Loss: 5.6866
# Validation Loss: 5.7044
# Random Target Sentence: lovely you were a big help <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 384/512
# Train Loss: 5.6769
# Validation Loss: 5.7060
# Random Target Sentence: you are taking us to that holding cell now all right cut <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 416/512
# Train Loss: 5.6590
# Validation Loss: 5.7063
# Random Target Sentence: king of the who <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 448/512
# Train Loss: 5.6722
# Validation Loss: 5.6860
# Random Target Sentence: i do not believe it you are lying <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 480/512
# Train Loss: 5.6466
# Validation Loss: 5.6856
# Random Target Sentence: yeah he is keeping an eye out said he would call us if he sees anything that is about it for tonight <EOS> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 512/512
# Train Loss: 5.6557
# Validation Loss: 5.6526
# Random Target Sentence: then you should not even be around it you know it is <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 32/512
# Train Loss: 5.5595
# Validation Loss: 5.6552
# Random Target Sentence: part the gates of heaven as it were <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 64/512
# Train Loss: 5.6143
# Validation Loss: 5.6479
# Random Target Sentence: no you wo not <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 96/512
# Train Loss: 5.6249
# Validation Loss: 5.6187
# Random Target Sentence: trying to breathe <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 128/512
# Train Loss: 5.5805
# Validation Loss: 5.6104
# Random Target Sentence: jennifer <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 160/512
# Train Loss: 5.5864
# Validation Loss: 5.5956
# Random Target Sentence: do not worry she is good with kids <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 192/512
# Train Loss: 5.5600
# Validation Loss: 5.5744
# Random Target Sentence: a key party <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 224/512
# Train Loss: 5.5454
# Validation Loss: 5.5394
# Random Target Sentence: good evening commander everything ready <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 256/512
# Train Loss: 5.5202
# Validation Loss: 5.5083
# Random Target Sentence: we got married at the city hall and i think it gave bad luck the whole marriage <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i i i <EOS> <EOS> <EOS> <EOS> <EOS> not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 288/512
# Train Loss: 5.5471
# Validation Loss: 5.4821
# Random Target Sentence: i am goin to try and keep from it as much as i can <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> am <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 320/512
# Train Loss: 5.4846
# Validation Loss: 5.4619
# Random Target Sentence: what <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 352/512
# Train Loss: 5.4790
# Validation Loss: 5.4331
# Random Target Sentence: who does <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 384/512
# Train Loss: 5.4484
# Validation Loss: 5.4198
# Random Target Sentence: c amon we will walk and talk <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> am <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 416/512
# Train Loss: 5.4361
# Validation Loss: 5.4034
# Random Target Sentence: why <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 448/512
# Train Loss: 5.3852
# Validation Loss: 5.3757
# Random Target Sentence: the doctor will be back in a minute <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 480/512
# Train Loss: 5.4051
# Validation Loss: 5.3693
# Random Target Sentence: huh <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 512/512
# Train Loss: 5.3727
# Validation Loss: 5.3427
# Random Target Sentence: california <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 32/512
# Train Loss: 5.2887
# Validation Loss: 5.3102
# Random Target Sentence: forget i said wife <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> do <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 64/512
# Train Loss: 5.2959
# Validation Loss: 5.3058
# Random Target Sentence: i can not read ma am i just look at the pictures <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am not know <EOS> <EOS> not am <EOS> <EOS> <EOS> to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 96/512
# Train Loss: 5.2864
# Validation Loss: 5.2909
# Random Target Sentence: i do not know if this would be a wise move <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do not know <EOS> <EOS> <EOS> not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 128/512
# Train Loss: 5.3131
# Validation Loss: 5.2919
# Random Target Sentence: danny it is not what you think <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i is not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 160/512
# Train Loss: 5.2838
# Validation Loss: 5.2715
# Random Target Sentence: taking genesis away from us <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 192/512
# Train Loss: 5.3006
# Validation Loss: 5.2839
# Random Target Sentence: he is dead <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 224/512
# Train Loss: 5.2459
# Validation Loss: 5.2701
# Random Target Sentence: we got to do something nice for him <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do <EOS> are not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 256/512
# Train Loss: 5.2191
# Validation Loss: 5.2348
# Random Target Sentence: i found out i was pregnant and it scared the shit out of me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am <EOS> <EOS> am <EOS> <EOS> i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 288/512
# Train Loss: 5.2395
# Validation Loss: 5.2305
# Random Target Sentence: i am afraid i do not understand <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am not <EOS> am not know <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 320/512
# Train Loss: 5.1978
# Validation Loss: 5.2218
# Random Target Sentence: do what <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 352/512
# Train Loss: 5.2145
# Validation Loss: 5.2169
# Random Target Sentence: you comin to l a when <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are <EOS> <EOS> <EOS> a <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 384/512
# Train Loss: 5.2043
# Validation Loss: 5.2171
# Random Target Sentence: oh like i am not an interesting person <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i you am not know <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 416/512
# Train Loss: 5.2133
# Validation Loss: 5.1890
# Random Target Sentence: the other place what is that <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> is <EOS> not is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 448/512
# Train Loss: 5.1585
# Validation Loss: 5.1992
# Random Target Sentence: guess we know where mr price is now <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> are <EOS> <EOS> <EOS> <EOS> not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 480/512
# Train Loss: 5.2146
# Validation Loss: 5.1745
# Random Target Sentence: it happens to me all the time <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i you <EOS> <EOS> <EOS> little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 512/512
# Train Loss: 5.1190
# Validation Loss: 5.1884
# Random Target Sentence: i never make plans that far ahead <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am <EOS> <EOS> <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 32/512
# Train Loss: 5.1356
# Validation Loss: 5.1681
# Random Target Sentence: i thought they was <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am you are <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 64/512
# Train Loss: 5.1573
# Validation Loss: 5.1514
# Random Target Sentence: just one of norman is many secrets <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are <EOS> <EOS> <EOS> a <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 96/512
# Train Loss: 5.1389
# Validation Loss: 5.1437
# Random Target Sentence: do you hear from him son <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you know <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 128/512
# Train Loss: 5.1199
# Validation Loss: 5.1422
# Random Target Sentence: almost quaint <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 160/512
# Train Loss: 5.1414
# Validation Loss: 5.1226
# Random Target Sentence: sh <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> is
#
# Epoch: 4/20, Batch: 192/512
# Train Loss: 5.0899
# Validation Loss: 5.1085
# Random Target Sentence: pour that back <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 224/512
# Train Loss: 5.1328
# Validation Loss: 5.1039
# Random Target Sentence: a statement <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 256/512
# Train Loss: 5.0552
# Validation Loss: 5.1023
# Random Target Sentence: that was for christmas <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is not the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 288/512
# Train Loss: 5.1048
# Validation Loss: 5.0961
# Random Target Sentence: and that is <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i is not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> a <EOS> <EOS> <EOS> <EOS> <EOS> a <EOS> <EOS>
#
# Epoch: 4/20, Batch: 320/512
# Train Loss: 5.0588
# Validation Loss: 5.0769
# Random Target Sentence: you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 352/512
# Train Loss: 5.0415
# Validation Loss: 5.0846
# Random Target Sentence: know where he is <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i is is not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 384/512
# Train Loss: 5.0831
# Validation Loss: 5.0677
# Random Target Sentence: which is a long dull story and i wo not get into it but <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: you <EOS> a <EOS> <EOS> <EOS> <EOS> you do not know <EOS> <EOS> <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 416/512
# Train Loss: 5.0906
# Validation Loss: 5.0570
# Random Target Sentence: no last time i said i love you alex <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> do <EOS> am <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 448/512
# Train Loss: 5.0281
# Validation Loss: 5.0500
# Random Target Sentence: hey two hearts got busted last time maybe she is not over it either <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> is the the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 480/512
# Train Loss: 5.0290
# Validation Loss: 5.0484
# Random Target Sentence: where is the austrian is friedman the austrian <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> not <EOS> little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 512/512
# Train Loss: 5.0466
# Validation Loss: 5.0450
# Random Target Sentence: and your father <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i way <EOS> <EOS> <EOS> <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> is <EOS> <EOS>
#
# Epoch: 5/20, Batch: 32/512
# Train Loss: 5.0045
# Validation Loss: 5.0344
# Random Target Sentence: i know how the feds like to sit on information i got something in the car to show you <EOS> <PAD> <PAD> <PAD>
# Random Output Sentence: i am i is little is you be <EOS> <EOS> <EOS> am <EOS> <EOS> the little <EOS> be <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 64/512
# Train Loss: 5.0213
# Validation Loss: 5.0268
# Random Target Sentence: yeah i knew you would catch on eventually <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> am you are know <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 96/512
# Train Loss: 5.0376
# Validation Loss: 5.0270
# Random Target Sentence: i stopped rolling houses in the sixth grade mom get out of my room <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am to <EOS> <EOS> the little <EOS> <EOS> <EOS> <EOS> <EOS> the little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 128/512
# Train Loss: 4.9873
# Validation Loss: 5.0311
# Random Target Sentence: they are fine everybody i else i is fine <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are a <EOS> <EOS> do <EOS> am not <EOS> to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 160/512
# Train Loss: 5.0472
# Validation Loss: 5.0097
# Random Target Sentence: listen to you you sound like betty all pissed off because archie is taking veronica <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: you <EOS> you <EOS> are <EOS> to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 192/512
# Train Loss: 5.0190
# Validation Loss: 5.0057
# Random Target Sentence: now <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 224/512
# Train Loss: 5.0085
# Validation Loss: 5.0113
# Random Target Sentence: i thought maybe held gotten over that <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am you i <EOS> <EOS> <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 256/512
# Train Loss: 5.0074
# Validation Loss: 5.0031
# Random Target Sentence: no <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 288/512
# Train Loss: 4.9922
# Validation Loss: 5.0027
# Random Target Sentence: sure <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 320/512
# Train Loss: 4.9892
# Validation Loss: 5.0035
# Random Target Sentence: yeah <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 352/512
# Train Loss: 5.0004
# Validation Loss: 4.9945
# Random Target Sentence: no accident i tried to warn all of you about krueger <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> am <EOS> see you <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 384/512
# Train Loss: 4.9446
# Validation Loss: 4.9924
# Random Target Sentence: will you kiss me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you are <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 416/512
# Train Loss: 4.9755
# Validation Loss: 4.9870
# Random Target Sentence: might not need a gesture quite so grand what were you doing the very moment the baron is curse fell on the world <EOS> <PAD> <PAD>
# Random Output Sentence: i you you <EOS> way <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> car <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> the little <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 448/512
# Train Loss: 4.9390
# Validation Loss: 4.9913
# Random Target Sentence: a cure <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 480/512
# Train Loss: 4.9403
# Validation Loss: 4.9612
# Random Target Sentence: true <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 512/512
# Train Loss: 4.9417
# Validation Loss: 4.9668
# Random Target Sentence: madness <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 32/512
# Train Loss: 4.9140
# Validation Loss: 4.9556
# Random Target Sentence: no it was so right it scares me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you is not <EOS> <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 64/512
# Train Loss: 4.9233
# Validation Loss: 4.9581
# Random Target Sentence: i thought maybe you wanted me to see the kind of work the competition was turning out <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am i i <EOS> to <EOS> do you man <EOS> the <EOS> little <EOS> not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 96/512
# Train Loss: 4.9389
# Validation Loss: 4.9578
# Random Target Sentence: what <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 128/512
# Train Loss: 4.8988
# Validation Loss: 4.9542
# Random Target Sentence: i know but it was not all bad was it in fact i think you found it quite pleasurable mmmmm so soft so sensual <EOS> <PAD>
# Random Output Sentence: i am i i is a know the <EOS> not is the <EOS> am i are <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 160/512
# Train Loss: 4.8987
# Validation Loss: 4.9564
# Random Target Sentence: yeah <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 192/512
# Train Loss: 4.9171
# Validation Loss: 4.9459
# Random Target Sentence: vivian is in sales <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 224/512
# Train Loss: 4.9403
# Validation Loss: 4.9330
# Random Target Sentence: to join with him <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 256/512
# Train Loss: 4.9572
# Validation Loss: 4.9396
# Random Target Sentence: charged <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 288/512
# Train Loss: 4.9356
# Validation Loss: 4.9318
# Random Target Sentence: yeah except a chance in hell of coming out of this intact <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> little <EOS> the <EOS> the <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 320/512
# Train Loss: 4.9131
# Validation Loss: 4.9352
# Random Target Sentence: that is the air force base <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is the house <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 352/512
# Train Loss: 4.9249
# Validation Loss: 4.9183
# Random Target Sentence: i am gon na kill him <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am not na do <EOS> to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 384/512
# Train Loss: 4.8792
# Validation Loss: 4.9140
# Random Target Sentence: are you going to make me beg <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you <EOS> to get <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 416/512
# Train Loss: 4.9087
# Validation Loss: 4.9121
# Random Target Sentence: do you think it is been easy for me it is been years al can not have sex <EOS> <PAD> <PAD> <PAD>
# Random Output Sentence: i not have <EOS> is not a <EOS> a <EOS> is not <EOS> <EOS> <EOS> not <EOS> to <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 448/512
# Train Loss: 4.9427
# Validation Loss: 4.9104
# Random Target Sentence: i i do not know <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am do not know <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 480/512
# Train Loss: 4.8928
# Validation Loss: 4.9043
# Random Target Sentence: of course wow you look extremely beautiful <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i course i <EOS> are <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 512/512
# Train Loss: 4.9017
# Validation Loss: 4.9163
# Random Target Sentence: i uh um <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 32/512
# Train Loss: 4.8884
# Validation Loss: 4.9175
# Random Target Sentence: oh yeah <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 64/512
# Train Loss: 4.8259
# Validation Loss: 4.9088
# Random Target Sentence: they are real good <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 96/512
# Train Loss: 4.8898
# Validation Loss: 4.8944
# Random Target Sentence: they are not interested jake <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not a <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 128/512
# Train Loss: 4.8304
# Validation Loss: 4.8987
# Random Target Sentence: george do not be so emotional this is business besides i can not kill you you are my brother <EOS> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> you know <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> am not know <EOS> <EOS> <EOS> not lot <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 160/512
# Train Loss: 4.8380
# Validation Loss: 4.8923
# Random Target Sentence: so it is ok if i bring her <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> is a <EOS> you am <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> to <EOS>
#
# Epoch: 7/20, Batch: 192/512
# Train Loss: 4.8835
# Validation Loss: 4.8820
# Random Target Sentence: you remember samuel my son <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are <EOS> i little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 224/512
# Train Loss: 4.8298
# Validation Loss: 4.8876
# Random Target Sentence: i stopped rolling houses in the sixth grade mom get out of my room <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am you <EOS> <EOS> the little <EOS> <EOS> <EOS> you <EOS> the job <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 256/512
# Train Loss: 4.8509
# Validation Loss: 4.8839
# Random Target Sentence: let me worry about the club <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> to <EOS> me guy me <EOS> <EOS> <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 288/512
# Train Loss: 4.9090
# Validation Loss: 4.8662
# Random Target Sentence: it is for your own safety now what can you tell us about sergeant john vincennes <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is a the <EOS> <EOS> <EOS> <EOS> <EOS> you <EOS> me <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 320/512
# Train Loss: 4.8176
# Validation Loss: 4.8779
# Random Target Sentence: what <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 352/512
# Train Loss: 4.8550
# Validation Loss: 4.8720
# Random Target Sentence: that is my business <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is the name <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 384/512
# Train Loss: 4.8443
# Validation Loss: 4.8689
# Random Target Sentence: not entirely <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 416/512
# Train Loss: 4.8666
# Validation Loss: 4.8685
# Random Target Sentence: yes <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 448/512
# Train Loss: 4.8707
# Validation Loss: 4.8585
# Random Target Sentence: of course you are all right ed <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i course <EOS> are not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 480/512
# Train Loss: 4.8009
# Validation Loss: 4.8633
# Random Target Sentence: yep there is some great places nearby <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> is a little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 512/512
# Train Loss: 4.8894
# Validation Loss: 4.8571
# Random Target Sentence: are all of you named jones <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you <EOS> course have <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 32/512
# Train Loss: 4.7856
# Validation Loss: 4.8600
# Random Target Sentence: what else what else did he indicate to you i need to know everything he said <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is <EOS> is <EOS> you do <EOS> do <EOS> do to be <EOS> <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 64/512
# Train Loss: 4.8006
# Validation Loss: 4.8610
# Random Target Sentence: four nights how did you sleep <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 96/512
# Train Loss: 4.7834
# Validation Loss: 4.8505
# Random Target Sentence: right as rain <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 128/512
# Train Loss: 4.8023
# Validation Loss: 4.8520
# Random Target Sentence: they are eggs <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 160/512
# Train Loss: 4.8236
# Validation Loss: 4.8428
# Random Target Sentence: honestly you would do if only you had the buck teeth <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is are not not you <EOS> want me time <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 192/512
# Train Loss: 4.8142
# Validation Loss: 4.8472
# Random Target Sentence: yeah well anyway i also wanted to tell you i am not getting married <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> i <EOS> am to to be me <EOS> do going know <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 224/512
# Train Loss: 4.8039
# Validation Loss: 4.8406
# Random Target Sentence: i am sorry <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 256/512
# Train Loss: 4.8145
# Validation Loss: 4.8462
# Random Target Sentence: you do not got a headache <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not know a little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 288/512
# Train Loss: 4.8388
# Validation Loss: 4.8441
# Random Target Sentence: which is <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you a <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 320/512
# Train Loss: 4.8345
# Validation Loss: 4.8382
# Random Target Sentence: you know how i spent last weekend walking his damned dog <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are <EOS> do am <EOS> <EOS> <EOS> <EOS> time <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 352/512
# Train Loss: 4.8253
# Validation Loss: 4.8376
# Random Target Sentence: yes <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 384/512
# Train Loss: 4.7724
# Validation Loss: 4.8370
# ...
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 256/512
# Train Loss: 4.5757
# Validation Loss: 4.6772
# Random Target Sentence: mikey williams <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 288/512
# Train Loss: 4.5127
# Validation Loss: 4.6774
# Random Target Sentence: you are i have seen you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not am to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> you you <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 320/512
# Train Loss: 4.5681
# Validation Loss: 4.6764
# Random Target Sentence: what <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 352/512
# Train Loss: 4.5611
# Validation Loss: 4.6776
# Random Target Sentence: you preacher <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 384/512
# Train Loss: 4.5526
# Validation Loss: 4.6769
# Random Target Sentence: you know the insides of those are filled with stuff that gives you cancer <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are what hell <EOS> course <EOS> not <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 416/512
# Train Loss: 4.5232
# Validation Loss: 4.6766
# Random Target Sentence: schofield you from schofield <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> are me <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 448/512
# Train Loss: 4.5498
# Validation Loss: 4.6761
# Random Target Sentence: well he is not that strange do not say that <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i is a a <EOS> <EOS> not be <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 480/512
# Train Loss: 4.5580
# Validation Loss: 4.6760
# Random Target Sentence: i have been doing a lot of thinking <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am not here you little of the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 512/512
# Train Loss: 4.5754
# Validation Loss: 4.6750
# Random Target Sentence: why me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 32/512
# Train Loss: 4.5258
# Validation Loss: 4.6760
# Random Target Sentence: let him go he said let him go <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i me <EOS> to is i me <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> me <EOS> <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 64/512
# Train Loss: 4.5834
# Validation Loss: 4.6748
# Random Target Sentence: which is it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 96/512
# Train Loss: 4.5633
# Validation Loss: 4.6752
# Random Target Sentence: go ahead i can not reach feet <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i on <EOS> am not be <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 128/512
# Train Loss: 4.5381
# Validation Loss: 4.6765
# Random Target Sentence: they are newspaper men mollie they can not help themselves the lord made them that way <EOS> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not <EOS> <EOS> <EOS> are not be you <EOS> money <EOS> me <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 160/512
# Train Loss: 4.5551
# Validation Loss: 4.6765
# Random Target Sentence: ian <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 192/512
# Train Loss: 4.4894
# Validation Loss: 4.6768
# Random Target Sentence: hey come on we have got to have at least one victory party <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you on <EOS> are to to be to the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 224/512
# Train Loss: 4.5605
# Validation Loss: 4.6751
# Random Target Sentence: they did not i tell i me anything they asked questions <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not know do you am you <EOS> are you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 256/512
# Train Loss: 4.5440
# Validation Loss: 4.6745
# Random Target Sentence: i changed it see you later mr travis that guy has a problem maggie you can run everyone is life but your own <EOS>
# Random Output Sentence: i am <EOS> is you <EOS> <EOS> way <EOS> is <EOS> been good <EOS> <EOS> are not <EOS> <EOS> not <EOS> i name <EOS>
#
# Epoch: 19/20, Batch: 288/512
# Train Loss: 4.5443
# Validation Loss: 4.6746
# Random Target Sentence: jamie needs a halloween costume <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i me <EOS> little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 320/512
# Train Loss: 4.5417
# Validation Loss: 4.6756
# Random Target Sentence: i will see you tomorrow <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am be you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 352/512
# Train Loss: 4.5654
# Validation Loss: 4.6738
# Random Target Sentence: if you do not complete the assignment you will get a zero for the day <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you do not know to other <EOS> know be a little <EOS> the whole <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 384/512
# Train Loss: 4.4809
# Validation Loss: 4.6747
# Random Target Sentence: maybe <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 416/512
# Train Loss: 4.5402
# Validation Loss: 4.6747
# Random Target Sentence: oh please destiny is just something we have invented because we can not stand the fact that everything that happens is accidental <EOS> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> it a <EOS> are to <EOS> i are not be it other <EOS> is <EOS> is <EOS> a <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 448/512
# Train Loss: 4.5788
# Validation Loss: 4.6744
# Random Target Sentence: thank you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 480/512
# Train Loss: 4.5699
# Validation Loss: 4.6747
# Random Target Sentence: and the white house <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you hell <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 512/512
# Train Loss: 4.6015
# Validation Loss: 4.6739
# Random Target Sentence: ah love well of course in italy we know nothing about that <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i to i the <EOS> the <EOS> are what <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 32/512
# Train Loss: 4.5425
# Validation Loss: 4.6734
# Random Target Sentence: face it ellen i am not the type of person who reads bedtime stories but you love me anyway <EOS> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> is <EOS> am not <EOS> fuck <EOS> the <EOS> is <EOS> <EOS> <EOS> i are <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 64/512
# Train Loss: 4.5450
# Validation Loss: 4.6732
# Random Target Sentence: i have expectations too <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am to to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 96/512
# Train Loss: 4.5549
# Validation Loss: 4.6744
# Random Target Sentence: me of course not that is why you are here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> course <EOS> <EOS> is <EOS> not are not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 128/512
# Train Loss: 4.5401
# Validation Loss: 4.6740
# Random Target Sentence: i am afraid of who i am <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do sorry i course is am not <EOS> <EOS> <EOS> <EOS> <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 160/512
# Train Loss: 4.5804
# Validation Loss: 4.6726
# Random Target Sentence: i am sure <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 192/512
# Train Loss: 4.5445
# Validation Loss: 4.6732
# Random Target Sentence: it is always a mistake to run away always <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is not <EOS> little <EOS> me <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 224/512
# Train Loss: 4.5635
# Validation Loss: 4.6732
# Random Target Sentence: oh mrs rand <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 256/512
# Train Loss: 4.5355
# Validation Loss: 4.6738
# Random Target Sentence: ever heard of the sullivan act <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i to <EOS> the time <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 288/512
# Train Loss: 4.5271
# Validation Loss: 4.6736
# Random Target Sentence: yes john made quite a study of the whole museum he had a copy of my original plans <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> it <EOS> good <EOS> the way <EOS> <EOS> is a little <EOS> the wife <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 320/512
# Train Loss: 4.5577
# Validation Loss: 4.6736
# Random Target Sentence: where are you going <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is you going to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 352/512
# Train Loss: 4.5517
# Validation Loss: 4.6731
# Random Target Sentence: ben think about all the people we can help if this works <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> he <EOS> <EOS> way <EOS> are not <EOS> he <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 384/512
# Train Loss: 4.5269
# Validation Loss: 4.6726
# Random Target Sentence: did not you tell her <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i you be <EOS> me <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 416/512
# Train Loss: 4.5227
# Validation Loss: 4.6730
# Random Target Sentence: promise <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 448/512
# Train Loss: 4.5635
# Validation Loss: 4.6727
# Random Target Sentence: he is such a loser <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is not a little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> of <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 480/512
# Train Loss: 4.5643
# Validation Loss: 4.6728
# Random Target Sentence: we do not go into your courts <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not know <EOS> the own <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 512/512
# Train Loss: 4.5300
# Validation Loss: 4.6726
# Random Target Sentence: you thought it was just <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are i is not a <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> me <EOS>

# %%
plt.plot(np.linspace(1,10,len(train_losses)),train_losses, label='Train Loss')
plt.plot(np.linspace(1,10,len(val_losses)),val_losses, label='Validation Loss')
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.title('Train Loss vs Validation Loss')
plt.legend()
plt.show()

# %%
PATH = './'
pickle_dump(train_losses, PATH,'train_losses_10.pkl')
pickle_dump(val_losses, PATH,'val_losses_10.pkl')

# %%
accumulation_batches = 4
epochs = 20 

model = TransformerModel(vocab_size=len(vocab.word2index),d_model=d_model,pad_id=vocab.word2index["<PAD>"],
                        encoder_layers=encoder_layers,decoder_layers=decoder_layers,dim_feedforward=feed_forward_dim,
                        num_heads=nheads,dropout_transformer=dropout_transformer, dropout_posenconding=dropout_posenconding).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=vocab.word2index["<PAD>"])
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,'min',patience=patience, factor=0.8)

train_losses, val_losses, model, optimizer = train_ga(epochs, model, criterion, optimizer, train_loader,
                                                                    device, val_loader, accumulation_batches, lr_scheduler, eval_every_n_batches)
# Out:
# Epoch: 1/20, Batch: 32/512
# Train Loss: 8.5063
# Validation Loss: 8.1579
# Random Target Sentence: why do mice go where there is cheese <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 64/512
# Train Loss: 8.0842
# Validation Loss: 7.8014
# Random Target Sentence: i killed him and cut him and ate all of him i left nothing for you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 96/512
# Train Loss: 7.7424
# Validation Loss: 7.5371
# Random Target Sentence: what guy <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 128/512
# Train Loss: 7.5934
# Validation Loss: 7.3003
# Random Target Sentence: oh yeah <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 160/512
# Train Loss: 7.3357
# Validation Loss: 7.0829
# Random Target Sentence: but then why do you want to kill a hundred and sixty million of our people sir <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 192/512
# Train Loss: 7.1773
# Validation Loss: 6.8869
# Random Target Sentence: really already the summer is just begun <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 224/512
# Train Loss: 6.8902
# Validation Loss: 6.7004
# Random Target Sentence: oh yeah <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 256/512
# Train Loss: 6.7343
# Validation Loss: 6.5180
# Random Target Sentence: you did not <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 288/512
# Train Loss: 6.5677
# Validation Loss: 6.3573
# Random Target Sentence: i was out in the garden mama came out and told me when she saw it on tv why did not you call me <EOS> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 320/512
# Train Loss: 6.4130
# Validation Loss: 6.2246
# Random Target Sentence: yes <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 352/512
# Train Loss: 6.2979
# Validation Loss: 6.1168
# Random Target Sentence: do not say that <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 384/512
# Train Loss: 6.1623
# Validation Loss: 6.0045
# Random Target Sentence: you are a good soldier bill <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 416/512
# Train Loss: 6.0166
# Validation Loss: 5.9293
# Random Target Sentence: he is just being like all parents concerned about the ones they love <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 448/512
# Train Loss: 5.9934
# Validation Loss: 5.8697
# Random Target Sentence: okay i will keep digging <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 480/512
# Train Loss: 5.9224
# Validation Loss: 5.8184
# Random Target Sentence: well you better get the money somehow six o clock and come alone if you do not we will destroy the tapes <EOS>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 1/20, Batch: 512/512
# Train Loss: 5.8670
# Validation Loss: 5.7804
# Random Target Sentence: thank you tell me what do those words mean beloved husband beloved son beloved wife <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 32/512
# Train Loss: 5.7374
# Validation Loss: 5.7534
# Random Target Sentence: i do i just said that i was never here before i actually like it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 64/512
# Train Loss: 5.7262
# Validation Loss: 5.7309
# Random Target Sentence: a million years behind us jorel he is only a baby <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 96/512
# Train Loss: 5.7404
# Validation Loss: 5.7198
# Random Target Sentence: i am trying to tell you it is on the lady is pillow <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 128/512
# Train Loss: 5.7702
# Validation Loss: 5.7091
# Random Target Sentence: and one other thing <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 160/512
# Train Loss: 5.6826
# Validation Loss: 5.7025
# Random Target Sentence: promise <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 192/512
# Train Loss: 5.7283
# Validation Loss: 5.7004
# Random Target Sentence: no your kids <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 224/512
# Train Loss: 5.6859
# Validation Loss: 5.6969
# Random Target Sentence: what <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 256/512
# Train Loss: 5.6726
# Validation Loss: 5.6911
# Random Target Sentence: walter jeez <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 288/512
# Train Loss: 5.6663
# Validation Loss: 5.6907
# Random Target Sentence: make me forget it baby <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 320/512
# Train Loss: 5.7048
# Validation Loss: 5.6893
# Random Target Sentence: excuse me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 352/512
# Train Loss: 5.7612
# Validation Loss: 5.6856
# Random Target Sentence: maggie maggie is little girl <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 384/512
# Train Loss: 5.6850
# Validation Loss: 5.6865
# Random Target Sentence: thanks i will <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 416/512
# Train Loss: 5.6390
# Validation Loss: 5.6798
# Random Target Sentence: why would i do that <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 448/512
# Train Loss: 5.7473
# Validation Loss: 5.6745
# Random Target Sentence: boy i would love to but i am going to hollywood <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 480/512
# Train Loss: 5.6816
# Validation Loss: 5.6745
# Random Target Sentence: no we talked about history and siberian geese <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 2/20, Batch: 512/512
# Train Loss: 5.6306
# Validation Loss: 5.6598
# Random Target Sentence: the hell i can not <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 32/512
# Train Loss: 5.5773
# Validation Loss: 5.6596
# Random Target Sentence: you have seen enough <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 64/512
# Train Loss: 5.6241
# Validation Loss: 5.6564
# Random Target Sentence: loser oh yeah he was a loser alright a big loser <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 96/512
# Train Loss: 5.6484
# Validation Loss: 5.6530
# Random Target Sentence: you are so famous now <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 128/512
# Train Loss: 5.6541
# Validation Loss: 5.6537
# Random Target Sentence: perhaps it was a wrong number <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 160/512
# Train Loss: 5.6071
# Validation Loss: 5.6426
# Random Target Sentence: and are they going to get it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 192/512
# Train Loss: 5.5697
# Validation Loss: 5.6439
# Random Target Sentence: never gave it much thought <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 224/512
# Train Loss: 5.6540
# Validation Loss: 5.6324
# Random Target Sentence: i do not know are you in anthony <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 256/512
# Train Loss: 5.5958
# Validation Loss: 5.6284
# Random Target Sentence: i move for no man <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 288/512
# Train Loss: 5.6380
# Validation Loss: 5.6192
# Random Target Sentence: i love you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 320/512
# Train Loss: 5.5771
# Validation Loss: 5.6230
# Random Target Sentence: we went out a few times we did not have sex but we fooled around <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 352/512
# Train Loss: 5.5131
# Validation Loss: 5.6053
# Random Target Sentence: but you know he is dirty and you still wan na see him again <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 384/512
# Train Loss: 5.6201
# Validation Loss: 5.6088
# Random Target Sentence: i just got back i do not know which end is up <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 416/512
# Train Loss: 5.6579
# Validation Loss: 5.5887
# Random Target Sentence: ready as i will ever be <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 448/512
# Train Loss: 5.5433
# Validation Loss: 5.5802
# Random Target Sentence: you are not looking at your self you are looking at me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 480/512
# Train Loss: 5.5418
# Validation Loss: 5.5674
# Random Target Sentence: as soon as i met him you knew i would say yes he makes julia real for me <EOS> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 3/20, Batch: 512/512
# Train Loss: 5.4506
# Validation Loss: 5.5623
# Random Target Sentence: yes <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 32/512
# Train Loss: 5.5564
# Validation Loss: 5.5459
# Random Target Sentence: what are you looking at me like that for i already gave you my three hundred <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 64/512
# Train Loss: 5.5397
# Validation Loss: 5.5263
# Random Target Sentence: no <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i i you is you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> i i you i <EOS> i i i you <EOS> i
#
# Epoch: 4/20, Batch: 96/512
# Train Loss: 5.5211
# Validation Loss: 5.5252
# Random Target Sentence: oh purely scientific interest i am sure <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 128/512
# Train Loss: 5.4892
# Validation Loss: 5.5017
# Random Target Sentence: you really think so us <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 160/512
# Train Loss: 5.5644
# Validation Loss: 5.4877
# Random Target Sentence: oh no my friend <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 192/512
# Train Loss: 5.3936
# Validation Loss: 5.4757
# Random Target Sentence: no i am okay <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is am <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 224/512
# Train Loss: 5.4887
# Validation Loss: 5.4590
# Random Target Sentence: is that right dad <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 256/512
# Train Loss: 5.4920
# Validation Loss: 5.4434
# Random Target Sentence: yes i think so too it is been organized well but what will the french do <EOS> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> do <EOS> you <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> not <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 288/512
# Train Loss: 5.4341
# Validation Loss: 5.4296
# Random Target Sentence: show me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 320/512
# Train Loss: 5.5354
# Validation Loss: 5.4120
# Random Target Sentence: i have changed my mind i will come to moscow if you are still going <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am <EOS> <EOS> <EOS> <EOS> am <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 352/512
# Train Loss: 5.4087
# Validation Loss: 5.4124
# Random Target Sentence: what is your business <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 384/512
# Train Loss: 5.5124
# Validation Loss: 5.3767
# Random Target Sentence: good evening vincent <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 416/512
# Train Loss: 5.3260
# Validation Loss: 5.3690
# Random Target Sentence: how would you know that kay <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i not <EOS> <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 448/512
# Train Loss: 5.4599
# Validation Loss: 5.3587
# Random Target Sentence: you are right here is luck to you will turner <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 480/512
# Train Loss: 5.3085
# Validation Loss: 5.3558
# Random Target Sentence: anyone <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 4/20, Batch: 512/512
# Train Loss: 5.4838
# Validation Loss: 5.3338
# Random Target Sentence: i will convince you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am <EOS> <EOS> do <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> not you <EOS>
#
# Epoch: 5/20, Batch: 32/512
# Train Loss: 5.4080
# Validation Loss: 5.3281
# Random Target Sentence: what <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 64/512
# Train Loss: 5.2832
# Validation Loss: 5.3239
# Random Target Sentence: you do not even have to say it i will believe goodnight dear <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not know <EOS> a <EOS> <EOS> <EOS> am <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 96/512
# Train Loss: 5.3959
# Validation Loss: 5.3192
# Random Target Sentence: i wan na go double or nothing on the next game <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 128/512
# Train Loss: 5.3059
# Validation Loss: 5.3073
# Random Target Sentence: why it is coming on its own it does not hurt <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 160/512
# Train Loss: 5.3127
# Validation Loss: 5.3016
# Random Target Sentence: i am not talkin to him i am talkin to myself it helps me think <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do not do <EOS> <EOS> <EOS> am you to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 192/512
# Train Loss: 5.3523
# Validation Loss: 5.2993
# Random Target Sentence: jesus christ the man does not want to talk so get off his back an let is get on to some new business <EOS>
# Random Output Sentence: i <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 224/512
# Train Loss: 5.3048
# Validation Loss: 5.2814
# Random Target Sentence: stop being nuts <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 256/512
# Train Loss: 5.3037
# Validation Loss: 5.2822
# Random Target Sentence: come here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: you you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 288/512
# Train Loss: 5.2686
# Validation Loss: 5.2838
# Random Target Sentence: i like it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 320/512
# Train Loss: 5.2657
# Validation Loss: 5.2587
# Random Target Sentence: do you you told me they are survivors and they are but how much longer they survive is up to us <EOS> <PAD> <PAD> <PAD>
# Random Output Sentence: i not <EOS> <EOS> <EOS> <EOS> <EOS> not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> not <EOS> to <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 352/512
# Train Loss: 5.3648
# Validation Loss: 5.2582
# Random Target Sentence: i would have lied to me if i thought i would believe it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am not to not not <EOS> i am <EOS> am not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 384/512
# Train Loss: 5.3235
# Validation Loss: 5.2614
# Random Target Sentence: believe <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 416/512
# Train Loss: 5.2359
# Validation Loss: 5.2521
# Random Target Sentence: na <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 448/512
# Train Loss: 5.1530
# Validation Loss: 5.2460
# Random Target Sentence: it is past seven <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is not i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 480/512
# Train Loss: 5.2183
# Validation Loss: 5.2246
# Random Target Sentence: remark <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 5/20, Batch: 512/512
# Train Loss: 5.2631
# Validation Loss: 5.2370
# Random Target Sentence: no <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 32/512
# Train Loss: 5.2195
# Validation Loss: 5.2147
# Random Target Sentence: michael meyers <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 64/512
# Train Loss: 5.1090
# Validation Loss: 5.2175
# Random Target Sentence: if it rains i will buy myself an umbrella <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i is <EOS> am you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 96/512
# Train Loss: 5.1626
# Validation Loss: 5.2113
# Random Target Sentence: it is not cheap it is nice <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is not <EOS> <EOS> is not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 128/512
# Train Loss: 5.1654
# Validation Loss: 5.2073
# Random Target Sentence: me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 160/512
# Train Loss: 5.1844
# Validation Loss: 5.1982
# Random Target Sentence: and if he is not <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i i is not have <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 192/512
# Train Loss: 5.1934
# Validation Loss: 5.1807
# Random Target Sentence: turn over <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 224/512
# Train Loss: 5.2636
# Validation Loss: 5.1914
# Random Target Sentence: back on earth victor is medical facility we are in quarantine <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: is <EOS> <EOS> <EOS> <EOS> you <EOS> <EOS> have not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 256/512
# Train Loss: 5.1544
# Validation Loss: 5.1711
# Random Target Sentence: why did not they say that before you started <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 288/512
# Train Loss: 5.1592
# Validation Loss: 5.1762
# Random Target Sentence: cotton company <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 320/512
# Train Loss: 5.0793
# Validation Loss: 5.1712
# Random Target Sentence: all stop sir <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 352/512
# Train Loss: 5.1726
# Validation Loss: 5.1598
# Random Target Sentence: no i am gon na wait <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i am not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the <EOS>
#
# Epoch: 6/20, Batch: 384/512
# Train Loss: 5.2298
# Validation Loss: 5.1537
# Random Target Sentence: they are right behind the door <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not <EOS> <EOS> a <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 416/512
# Train Loss: 5.2004
# Validation Loss: 5.1520
# Random Target Sentence: where and do not tell me san francisco <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i you not have <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 448/512
# Train Loss: 5.0254
# Validation Loss: 5.1476
# Random Target Sentence: i seem to be forever thanking you for something do not i <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am you be you <EOS> <EOS> <EOS> <EOS> <EOS> not know am <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 480/512
# Train Loss: 5.2254
# Validation Loss: 5.1329
# Random Target Sentence: do not ever talk like that fran do not make yourself out to be cheap <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i not know <EOS> <EOS> <EOS> <EOS> <EOS> not know <EOS> <EOS> <EOS> be <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 6/20, Batch: 512/512
# Train Loss: 5.2007
# Validation Loss: 5.1264
# Random Target Sentence: i just turned twenty <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am be <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 32/512
# Train Loss: 5.1056
# Validation Loss: 5.1176
# Random Target Sentence: comes in different parts of the river every night a different part <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> a <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 64/512
# Train Loss: 5.1403
# Validation Loss: 5.1299
# Random Target Sentence: no he showed me one <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> is <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 96/512
# Train Loss: 5.1390
# Validation Loss: 5.1170
# Random Target Sentence: of course don t be silly <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 128/512
# Train Loss: 5.1224
# Validation Loss: 5.1030
# Random Target Sentence: you remember alison <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 160/512
# Train Loss: 5.0737
# Validation Loss: 5.1048
# Random Target Sentence: we will move them <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do know <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 192/512
# Train Loss: 5.1001
# Validation Loss: 5.0965
# Random Target Sentence: hold on a minute let is take the chance george <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> the <EOS> <EOS> a <EOS> little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 224/512
# Train Loss: 4.9798
# Validation Loss: 5.0977
# Random Target Sentence: excuse me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 256/512
# Train Loss: 4.9751
# Validation Loss: 5.0899
# Random Target Sentence: no i did not mean to sound negative it was but ben what is going to happen with us have you <EOS>
# Random Output Sentence: i i do not know you be <EOS> i is you you <EOS> <EOS> not <EOS> be <EOS> <EOS> <EOS> to <EOS>
#
# Epoch: 7/20, Batch: 288/512
# Train Loss: 5.0567
# Validation Loss: 5.0800
# Random Target Sentence: probably <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 320/512
# Train Loss: 5.1311
# Validation Loss: 5.0845
# Random Target Sentence: his boss was the one on the warren commission who handled all the leads to the intelligence community <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i the <EOS> not a <EOS> <EOS> little you <EOS> <EOS> <EOS> <EOS> little <EOS> be the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 352/512
# Train Loss: 5.0143
# Validation Loss: 5.0785
# Random Target Sentence: that is the key question <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 384/512
# Train Loss: 5.1187
# Validation Loss: 5.0741
# Random Target Sentence: maybe we should knock first <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i are are <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 416/512
# Train Loss: 5.0077
# Validation Loss: 5.0679
# Random Target Sentence: why <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 448/512
# Train Loss: 5.0153
# Validation Loss: 5.0596
# Random Target Sentence: whaddya mean i got your gun i got his money i got everything <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> am a little <EOS> am <EOS> time <EOS> am a <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 480/512
# Train Loss: 5.0053
# Validation Loss: 5.0636
# Random Target Sentence: right <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 7/20, Batch: 512/512
# Train Loss: 5.0400
# Validation Loss: 5.0567
# Random Target Sentence: i am sorry <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 32/512
# Train Loss: 4.9158
# Validation Loss: 5.0533
# Random Target Sentence: yeah well anyway i also wanted to tell you i am not getting married <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i i <EOS> am <EOS> <EOS> do <EOS> <EOS> am not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 64/512
# Train Loss: 4.9898
# Validation Loss: 5.0446
# Random Target Sentence: if i expected somethin i would not be still standin out here in the hall <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i do <EOS> <EOS> am not know the know <EOS> <EOS> <EOS> the little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 96/512
# Train Loss: 4.8635
# Validation Loss: 5.0414
# Random Target Sentence: when you have children i hope you will understand <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> are not <EOS> will <EOS> are be to <EOS> <EOS> <EOS> <EOS> <EOS> to <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> to <EOS>
#
# Epoch: 8/20, Batch: 128/512
# Train Loss: 5.0051
# Validation Loss: 5.0329
# Random Target Sentence: i still am <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do <EOS> not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 160/512
# Train Loss: 5.0163
# Validation Loss: 5.0381
# Random Target Sentence: no i just kept talking to her there was a lot of guys in that bar could a been any of them <EOS>
# Random Output Sentence: i i am not <EOS> <EOS> be <EOS> <EOS> not little <EOS> the <EOS> <EOS> <EOS> <EOS> not time <EOS> <EOS> the <EOS>
#
# Epoch: 8/20, Batch: 192/512
# Train Loss: 5.0390
# Validation Loss: 5.0296
# Random Target Sentence: that is what we are paid for <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is not <EOS> are you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 224/512
# Train Loss: 5.0264
# Validation Loss: 5.0208
# Random Target Sentence: agnes how are babies born <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> are you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 256/512
# Train Loss: 4.9485
# Validation Loss: 5.0180
# Random Target Sentence: i need you to bring me the scumbag who ran off with my wife so i can cut off his nuts <EOS> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am you <EOS> be <EOS> <EOS> lot <EOS> <EOS> <EOS> you you a <EOS> <EOS> am not <EOS> <EOS> little <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 288/512
# Train Loss: 5.0613
# Validation Loss: 5.0234
# Random Target Sentence: sh <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 320/512
# Train Loss: 4.8870
# Validation Loss: 5.0122
# Random Target Sentence: i came back for you this morning i came back before i even knew about the money you are what i want <EOS> <PAD> <PAD> <PAD>
# Random Output Sentence: i am <EOS> <EOS> you <EOS> is <EOS> am <EOS> <EOS> <EOS> am <EOS> <EOS> you little <EOS> <EOS> a <EOS> am to <EOS> <EOS> <EOS>
#
# Epoch: 8/20, Batch: 352/512
# Train Loss: 5.1311
# Validation Loss: 5.0242
# Random Target Sentence: yes and so do i but there are too few of us here to carry it too heavy <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> i <EOS> not am i is not <EOS> you the <EOS> <EOS> be <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# ...
# Random Output Sentence: i i me <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 256/512
# Train Loss: 4.6904
# Validation Loss: 4.7786
# Random Target Sentence: sam hi <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 288/512
# Train Loss: 4.7666
# Validation Loss: 4.7810
# Random Target Sentence: she had a new family not enough space for me said i should have moved in with her when we were kids but whatever <EOS> <PAD>
# Random Output Sentence: i is a little <EOS> <EOS> you <EOS> <EOS> a <EOS> <EOS> am be to <EOS> the me <EOS> <EOS> are <EOS> <EOS> i <EOS> <EOS>
#
# Epoch: 18/20, Batch: 320/512
# Train Loss: 4.7646
# Validation Loss: 4.7818
# Random Target Sentence: do not worry about it if it is off your collar and out of your eyes that is all i am going to ask <EOS>
# Random Output Sentence: i not know <EOS> it <EOS> i <EOS> not <EOS> lot <EOS> i <EOS> the little <EOS> <EOS> the the am not to be you
#
# Epoch: 18/20, Batch: 352/512
# Train Loss: 4.7485
# Validation Loss: 4.7806
# Random Target Sentence: where he always is <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is is have <EOS> <EOS> me <EOS> it <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 384/512
# Train Loss: 4.7173
# Validation Loss: 4.7805
# Random Target Sentence: i am running late here i just came back for my briefcase <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am not you <EOS> <EOS> am a <EOS> to you car <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 416/512
# Train Loss: 4.8697
# Validation Loss: 4.7795
# Random Target Sentence: eleven <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 448/512
# Train Loss: 4.7711
# Validation Loss: 4.7788
# Random Target Sentence: yes <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 480/512
# Train Loss: 4.6945
# Validation Loss: 4.7788
# Random Target Sentence: that is right <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is a <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> it <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 18/20, Batch: 512/512
# Train Loss: 4.7522
# Validation Loss: 4.7789
# Random Target Sentence: thanks for everything taylor will i see you again <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> the <EOS> <EOS> you do you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 32/512
# Train Loss: 4.7022
# Validation Loss: 4.7778
# Random Target Sentence: well then it all seems to be working out for you listen ms <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> is right <EOS> be a <EOS> <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 64/512
# Train Loss: 4.7655
# Validation Loss: 4.7775
# Random Target Sentence: no <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 96/512
# Train Loss: 4.7425
# Validation Loss: 4.7765
# Random Target Sentence: it would not be the same without you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is you be a little <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> me <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 128/512
# Train Loss: 4.7428
# Validation Loss: 4.7762
# Random Target Sentence: you can not you are afraid <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are not know are going <EOS> <EOS> <EOS> <EOS> it <EOS> <EOS> <EOS> <EOS> <EOS> it it it the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 160/512
# Train Loss: 4.6358
# Validation Loss: 4.7770
# Random Target Sentence: forget who i am where is this school located <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: no you <EOS> am not <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> it <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 192/512
# Train Loss: 4.8312
# Validation Loss: 4.7790
# Random Target Sentence: edie listen to me i want you to believe me i want to be with you <EOS> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> me <EOS> am to <EOS> be <EOS> <EOS> am to be a me <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 224/512
# Train Loss: 4.6923
# Validation Loss: 4.7797
# Random Target Sentence: what do you want it to be vivian my name is vivian <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is you know to <EOS> be a <EOS> father <EOS> not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 256/512
# Train Loss: 4.7395
# Validation Loss: 4.7789
# Random Target Sentence: i know the answer i know all there is to know about louis <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am i little <EOS> am i right is not do <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 288/512
# Train Loss: 4.7256
# Validation Loss: 4.7780
# Random Target Sentence: okay i will see you tomorrow night then <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> am be you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 320/512
# Train Loss: 4.6988
# Validation Loss: 4.7769
# Random Target Sentence: what about you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 352/512
# Train Loss: 4.8119
# Validation Loss: 4.7760
# Random Target Sentence: in fact we never knew she had any friends period <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i the <EOS> have have <EOS> is to place <EOS> <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 384/512
# Train Loss: 4.7949
# Validation Loss: 4.7759
# Random Target Sentence: sweet jesus <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 416/512
# Train Loss: 4.8357
# Validation Loss: 4.7759
# Random Target Sentence: the night we met <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i hell <EOS> are <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> a <EOS> <EOS>
#
# Epoch: 19/20, Batch: 448/512
# Train Loss: 4.6544
# Validation Loss: 4.7762
# Random Target Sentence: no take it i do not want your goddamn fifty cents <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> the <EOS> am not know to way <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 480/512
# Train Loss: 4.6840
# Validation Loss: 4.7760
# Random Target Sentence: good to see ya right this way <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> me you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 19/20, Batch: 512/512
# Train Loss: 4.6960
# Validation Loss: 4.7761
# Random Target Sentence: yes <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 32/512
# Train Loss: 4.8674
# Validation Loss: 4.7763
# Random Target Sentence: and you will come and get him <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i are be to i it <EOS> <EOS> <EOS> <EOS> <EOS> it <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the me
#
# Epoch: 20/20, Batch: 64/512
# Train Loss: 4.8231
# Validation Loss: 4.7763
# Random Target Sentence: i do not think so <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am not know you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 96/512
# Train Loss: 4.6954
# Validation Loss: 4.7761
# Random Target Sentence: no thank you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 128/512
# Train Loss: 4.6895
# Validation Loss: 4.7757
# Random Target Sentence: who else do you know who touches the world with synthetic hands <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is is not know <EOS> is <EOS> little <EOS> me <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 160/512
# Train Loss: 4.7619
# Validation Loss: 4.7758
# Random Target Sentence: it is cool you ai not got to apologize for your brothers they are big boys <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i is not <EOS> are not <EOS> to be <EOS> the father <EOS> <EOS> not man <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 192/512
# Train Loss: 4.5511
# Validation Loss: 4.7757
# Random Target Sentence: what do you know about them <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do you know <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 224/512
# Train Loss: 4.7987
# Validation Loss: 4.7755
# Random Target Sentence: i will tell <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am be you <EOS> you you it you you you you you you you you <EOS> you you you you <EOS> you it <EOS> it
#
# Epoch: 20/20, Batch: 256/512
# Train Loss: 4.6659
# Validation Loss: 4.7750
# Random Target Sentence: i have just come from the castle it is over <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i am got got to the little <EOS> <EOS> a <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 288/512
# Train Loss: 4.7324
# Validation Loss: 4.7747
# Random Target Sentence: you tell me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are me <EOS> <EOS> <EOS> <EOS> <EOS> me <EOS> <EOS> <EOS> <EOS> me me me me <EOS> me me <EOS> me <EOS> <EOS> me
#
# Epoch: 20/20, Batch: 320/512
# Train Loss: 4.5849
# Validation Loss: 4.7743
# Random Target Sentence: it is not just the cable system it is in the phone system as well the electronic net it is everywhere <EOS>
# Random Output Sentence: i is a a a little <EOS> <EOS> is a the little <EOS> <EOS> it <EOS> hell <EOS> <EOS> <EOS> not <EOS>
#
# Epoch: 20/20, Batch: 352/512
# Train Loss: 4.7885
# Validation Loss: 4.7745
# Random Target Sentence: please no <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 384/512
# Train Loss: 4.7456
# Validation Loss: 4.7748
# Random Target Sentence: nah <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> you <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 416/512
# Train Loss: 4.7592
# Validation Loss: 4.7749
# Random Target Sentence: you and honey <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i are the <EOS> <EOS> <EOS> <EOS> <EOS> it <EOS> <EOS> me <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> it <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 448/512
# Train Loss: 4.8318
# Validation Loss: 4.7747
# Random Target Sentence: i will meet you outside <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i do be you <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> the the it <EOS> the <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 480/512
# Train Loss: 4.5982
# Validation Loss: 4.7743
# Random Target Sentence: no no way i can not do this <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i i i <EOS> am not <EOS> not <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>
#
# Epoch: 20/20, Batch: 512/512
# Train Loss: 4.6117
# Validation Loss: 4.7744
# Random Target Sentence: forget it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Random Output Sentence: i <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> it <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <EOS>

# %%
plt.plot(np.linspace(1,epochs,len(train_losses)),train_losses, label='Train Loss')
plt.plot(np.linspace(1,epochs,len(val_losses)),val_losses, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Train Loss vs Validation Loss')
plt.legend()
plt.show()

# %%
PATH = './'
pickle_dump(train_losses, PATH,'train_ga_losses_20.pkl')
pickle_dump(val_losses, PATH,'val_ga_losses_20.pkl')

# %%
# Checkpointing
############################

PATH = './'
save_checkpoint = checkpoint(model,optimizer,path=PATH,save_name="checkpoint_dicts")
torch.save(model, PATH+'model.pt')
#model_state, optimizer_state = load_checkpoint(PATH+"checkpoint_dicts.pt")
#model = torch.load(PATH+'model.pt')

# %%
def get_greedy_answer(model, question, vocab, device, max_length=20):
    line,_ = process_sentence(question)
    line = line+['<EOS>']
    line = [vocab.word2index.get(word, vocab.word2index["<PAD>"]) for word in line]
    line = torch.tensor(line, dtype=torch.long).unsqueeze(0).to(device)
    target = torch.tensor([vocab.word2index["<SOS>"]], dtype=torch.long).unsqueeze(0).to(device)
    model.eval()
    with torch.no_grad():
        for _ in range(max_length):
            output = model(line,target)
            output = output.argmax(dim=-1)[:,-1]
            if output.item() == vocab.word2index["<EOS>"]:
                break
            target = torch.cat((target,output.unsqueeze(0)),dim=1)
    answer = " ".join([vocab.index2word[idx.item()] for idx in target.squeeze()[1:]])
    return answer



def get_topk_answers(model, question, vocab, device, k=5, max_length=20):
    line,_ = process_sentence(question)
    line = line+['<EOS>']
    line = [vocab.word2index.get(word, vocab.word2index["<PAD>"]) for word in line]
    line = torch.tensor(line).unsqueeze(0).to(device)
    target = torch.tensor([vocab.word2index["<SOS>"]], dtype=torch.long).unsqueeze(0).to(device)
    model.eval()
    with torch.no_grad():
        for _ in range(max_length):
            output = model(line,target)
            output = F.softmax(output, dim=-1)[0,-1,:].detach().cpu()
            topk_logits, topk_indices = torch.topk(output,k=k,dim=-1)
            p = F.softmax(topk_logits, dim=-1).numpy()
            w_idx = np.random.choice(topk_indices.squeeze(), p=p)
            if w_idx == vocab.word2index["<EOS>"]:
                break
            w_idx = torch.tensor(w_idx, dtype=torch.long).unsqueeze(0).unsqueeze(0).to(device)
            target = torch.cat((target,w_idx),dim=1)
    target = [vocab.index2word[idx.item()] for idx in target.squeeze()[1:]]
    return " ".join(target)

# %%
input1 = "Hello sir, how are you?"
input2 = "What is your name?"
input3 = "How old are you?"
print(get_greedy_answer(model, input1, vocab, device, max_length=20))
print(get_greedy_answer(model, input2, vocab, device, max_length=20))
print(get_greedy_answer(model, input3, vocab, device, max_length=20))
print(get_topk_answers(model, input1, vocab, device, max_length=20))
print(get_topk_answers(model, input2, vocab, device, max_length=20))
print(get_topk_answers(model, input3, vocab, device, max_length=20))
print(get_topk_answers(model, input1, vocab, device, max_length=20))
print(get_topk_answers(model, input2, vocab, device, max_length=20))
print(get_topk_answers(model, input3, vocab, device, max_length=20))
# Out:
# i am sorry
# i am sorry
# i am sorry
# what
# you can get out of a car and you are gon
# you are a lot and i do it was going
# i have a minute in this time in this way to get a little way to be in your little
# no no you do not know that i do
# i can not know that is all right and i am going to be in your way i am a
